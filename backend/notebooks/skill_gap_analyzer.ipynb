# %% [markdown]
# # Skill Gap Analyzer
# Analyzing user skills against job requirements to identify key learning areas.

# %%
import os
import json
import pandas as pd

# Setup environment
from dotenv import load_dotenv
load_dotenv('../.env')

print('Skill Gap Analyzer workspace ready.')
